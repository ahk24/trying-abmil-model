# %% [markdown]
# # normal feed forward

# %% [markdown]
# ## PROSTATE + BLADDER + BREAST

# %%
# Jupyter Notebook version of main.py

import numpy as np
import torch
import torch.optim as optim
import torch.utils.data as data
from torch.autograd import Variable
from torch.utils.data import random_split, ConcatDataset, DataLoader

# Import your dataset and models
from dataloader import HistopathologyDataset
from model import Attention, GatedAttention

# ---------------------------
# Set parameters manually:
# ---------------------------
epochs = 20
lr = 0.0005
reg = 1e-4
# Use your actual paths to the folder (or file) containing your .pt embeddings 
# and the CSV file with labels.
# (Note: if your HistopathologyDataset expects a directory, make sure you supply that.)
# Paths for Cancer Prostate
embeddings_dir_prostate = "/data/temporary/amirhosein/model_script_prostate/pt_files/"
labels_csv_prostate = "/data/temporary/amirhosein/Prostate_Project/prostate_tp53_labels.csv"

# Paths for Cancer Bladder
embeddings_dir_bladder = "/data/temporary/amirhosein/model_script_bladder/pt_files/"
labels_csv_bladder = "/data/temporary/amirhosein/bladder_project/bladder_tp53_labels.csv"

# Paths for Cancer Breast
embeddings_dir_breast = "/data/temporary/amirhosein/modelscript_breast/pt_files/"
labels_csv_breast = "/data/temporary/amirhosein/breast_Project(subdirectories)/breast_tp53_labels.csv"

input_dim = 1024
model_type = "attention"   # Choose either "attention" or "gated_attention"
no_cuda = False

cuda = (not no_cuda) and torch.cuda.is_available()

# ---------------------------
# Set seeds and print status:
# ---------------------------
torch.manual_seed(1)
if cuda:
    torch.cuda.manual_seed(1)
    print('\nGPU is ON!')

# ---------------------------
# Create dataset objects.
# ---------------------------
dataset_prostate = HistopathologyDataset(embeddings_dir_prostate, labels_csv_prostate)
dataset_bladder = HistopathologyDataset(embeddings_dir_bladder, labels_csv_bladder)
dataset_breast = HistopathologyDataset(embeddings_dir_breast, labels_csv_breast)


# Suppose you want 80% of Cancer C for training and 20% for testing.
total_prostate = len(dataset_prostate)
train_size_prostate = int(0.8 * total_prostate)
test_size_prostate  = total_prostate - train_size_prostate

dataset_prostate_train, dataset_prostate_test = random_split(dataset_prostate, [train_size_prostate, test_size_prostate])

train_dataset = ConcatDataset([dataset_breast, dataset_bladder, dataset_prostate_train])
test_dataset  = dataset_prostate_test  # held-out portion from Cancer C

loader_kwargs = {'num_workers': 0, 'pin_memory': True} if cuda else {}
train_loader = data.DataLoader(train_dataset, batch_size=1, shuffle=True, **loader_kwargs)
test_loader  = data.DataLoader(test_dataset, batch_size=1, shuffle=False, **loader_kwargs)

# ---------------------------
# Initialize the Model:
# ---------------------------
print('Initializing Model')
if model_type == 'attention':
    model = Attention(input_dim=input_dim)
elif model_type == 'gated_attention':
    model = GatedAttention(input_dim=input_dim)
else:
    raise ValueError("Unknown model type. Choose 'attention' or 'gated_attention'.")

if cuda:
    model.cuda()

optimizer = optim.Adam(model.parameters(), lr=lr, betas=(0.9, 0.999), weight_decay=reg)

# ---------------------------
# Define training and testing functions:
# ---------------------------
def train(epoch):
    model.train()
    train_loss = 0.0
    train_error = 0.0
    for batch_idx, (data_batch, label) in enumerate(train_loader):
        if cuda:
            data_batch, label = data_batch.cuda(), label.cuda()
        data_batch, label = Variable(data_batch), Variable(label)
    
        optimizer.zero_grad()
        loss, _ = model.calculate_objective(data_batch, label)
        train_loss += loss.item()
        error, _ = model.calculate_classification_error(data_batch, label)
        train_error += error
    
        loss.backward()
        optimizer.step()
    
    train_loss /= len(train_loader)
    train_error /= len(train_loader)
    print('Epoch: {}, Loss: {:.4f}, Train Error: {:.4f}'.format(epoch, train_loss, train_error))
    
def test():
    model.eval()
    test_loss = 0.0
    test_error = 0.0
    with torch.no_grad():
        for batch_idx, (data_batch, label) in enumerate(test_loader):
            if cuda:
                data_batch, label = data_batch.cuda(), label.cuda()
            data_batch, label = Variable(data_batch), Variable(label)
            loss, attention_weights = model.calculate_objective(data_batch, label)
            test_loss += loss.item()
            error, predicted_label = model.calculate_classification_error(data_batch, label)
            test_error += error
    
            if batch_idx < 5:
                print('\nTrue Bag Label: {}  Predicted Bag Label: {}'
                      .format(label.cpu().numpy()[0], predicted_label.cpu().numpy()[0]))
    
    test_loss /= len(test_loader)
    test_error /= len(test_loader)
    print('\nTest Set, Loss: {:.4f}, Test Error: {:.4f}'.format(test_loss, test_error))
    
# ---------------------------
# Run training and testing:
# ---------------------------
print('Start Training')
for epoch in range(1, epochs + 1):
    train(epoch)
print('Start Testing')
test()
# Out:
# GPU is ON!
# Warning: No matching .pt file found for slide id partial: 'TCGA-DK-A6B6'. Skipping this entry.
# Warning: No matching .pt file found for slide id partial: 'TCGA-XF-AAN3'. Skipping this entry.
# Warning: No matching .pt file found for slide id partial: 'TCGA-FD-A3B5'. Skipping this entry.
# Warning: No matching .pt file found for slide id partial: 'TCGA-ZF-AA54'. Skipping this entry.
# Warning: No matching .pt file found for slide id partial: 'TCGA-ZF-AA4W'. Skipping this entry.
# Warning: No matching .pt file found for slide id partial: 'TCGA-FD-A3SP'. Skipping this entry.
# Initializing Model
# Start Training
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JT-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A5ZX-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0CH-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-2F-A9KT'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1X6-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-PL-A8LV-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-GU-A42R'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0D9-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1X5-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-Y6-A8TL-01'. Combining 5 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7521-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13J'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A27V-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YC-A9TC'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-2F-A9KT'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0CG-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SH-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A140-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A13Y-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7523-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A9WI-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JJ-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XR-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7525-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0CJ-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XW-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A13E-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JC-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SL-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A73U-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XF-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A27W-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A145-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JI-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A13G-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-MG-AAMC-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13J'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1Y2-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-WW-A8ZI-01'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1Y3-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-3C-AALI-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13I'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0DA-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A0C8'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A13D-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-XQ-A8TA-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-X4-A8KS-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A13F-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XS-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A6VV-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XY-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A141-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-X4-A8KQ-01'. Combining 9 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1X7-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A3Z6-01'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-3C-AALJ-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-PL-A8LX-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1J9-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YC-A9TC'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EL'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-PL-A8LZ-01'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XB-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-S3-AA12-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XL-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0DB-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1J8-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7519-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SI-01'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XV-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A0C8'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-GU-A42R'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XZ-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XC-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-S3-AA15-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-PL-A8LY-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1Y1-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A27T-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JD-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-OK-A5Q2-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13I'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0CE-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EL'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-EW-A423-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SK-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A27R-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JE-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SJ-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A73X-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A27N-01'. Combining 2 files.
# Epoch: 1, Loss: 0.5433, Train Error: 0.2603
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A145-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-OK-A5Q2-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13I'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0CH-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7519-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JJ-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13J'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XV-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7525-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0D9-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-XQ-A8TA-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A73U-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XZ-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1X7-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1Y3-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XC-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7523-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SK-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JD-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A3Z6-01'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-MG-AAMC-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-Y6-A8TL-01'. Combining 5 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1X6-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A27T-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-X4-A8KQ-01'. Combining 9 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-S3-AA12-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YC-A9TC'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XW-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-PL-A8LV-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A27W-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A13F-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1J8-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13I'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7521-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-2F-A9KT'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A27R-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A13E-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XF-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-3C-AALI-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EL'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-2F-A9KT'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-3C-AALJ-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A13D-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XR-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0DB-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A140-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-PL-A8LZ-01'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JI-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A27N-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SL-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A73X-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EL'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SI-01'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-EW-A423-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-PL-A8LX-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1Y2-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JT-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1X5-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A0C8'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1Y1-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A141-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XY-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13J'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A0C8'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JE-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0CE-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-S3-AA15-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-WW-A8ZI-01'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-X4-A8KS-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SH-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SJ-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A13G-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XL-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1J9-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0CG-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A6VV-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A13Y-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0CJ-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0DA-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A9WI-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JC-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-GU-A42R'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YC-A9TC'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-GU-A42R'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-PL-A8LY-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A5ZX-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A27V-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XB-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XS-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Epoch: 2, Loss: 0.4700, Train Error: 0.2148
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A13D-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YC-A9TC'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XF-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A73U-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13I'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-S3-AA12-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A141-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7525-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A27T-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XZ-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A5ZX-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SH-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SK-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-PL-A8LZ-01'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-2F-A9KT'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1Y3-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EL'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-X4-A8KQ-01'. Combining 9 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-2F-A9KT'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SJ-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YC-A9TC'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1X5-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JT-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-XQ-A8TA-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SI-01'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A13Y-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13I'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XW-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0D9-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1Y2-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-3C-AALJ-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-EW-A423-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A73X-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XY-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XC-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A0C8'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7521-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XL-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-GU-A42R'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1Y1-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A3Z6-01'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1X7-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1J9-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A13F-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-Y6-A8TL-01'. Combining 5 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A13G-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JE-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JI-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XB-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A27V-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7519-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0CE-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-MG-AAMC-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1J8-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JC-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0CJ-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JD-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A13E-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-3C-AALI-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SL-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13J'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A27R-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-WW-A8ZI-01'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A6VV-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EL'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0CG-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-GU-A42R'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A145-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A27W-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JJ-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-OK-A5Q2-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A140-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-PL-A8LY-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0CH-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7523-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XS-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-X4-A8KS-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13J'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0DA-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A9WI-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A27N-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XR-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A0C8'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-PL-A8LV-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-PL-A8LX-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0DB-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-S3-AA15-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1X6-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XV-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Epoch: 3, Loss: 0.4248, Train Error: 0.1863
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SH-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7521-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EL'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XW-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SK-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YC-A9TC'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13I'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A27W-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-3C-AALJ-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A5ZX-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0CG-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JD-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-MG-AAMC-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7525-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A13D-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XV-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SL-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XF-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-PL-A8LX-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XB-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A13F-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A13E-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7519-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YC-A9TC'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1J9-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-3C-AALI-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JJ-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0CH-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XR-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SI-01'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-GU-A42R'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JE-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1Y2-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A27T-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A27N-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XY-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A0C8'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XS-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-Y6-A8TL-01'. Combining 5 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EL'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-S3-AA12-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7523-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-S3-AA15-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1J8-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-2F-A9KT'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1X6-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A140-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A0C8'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0DA-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A145-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JI-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-GU-A42R'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A73U-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13J'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-PL-A8LY-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1Y3-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1X7-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A13Y-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0DB-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A9WI-01'. Combining 4 files.
# ...
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JE-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A5ZX-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XZ-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-X4-A8KQ-01'. Combining 9 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1Y1-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A13Y-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XC-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0DA-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A73X-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0CH-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A0C8'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7521-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1J8-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1Y2-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-GU-A42R'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SI-01'. Combining 3 files.
# Epoch: 19, Loss: 0.0601, Train Error: 0.0206
# Warning: Multiple matches found for slide id partial: 'TCGA-X4-A8KQ-01'. Combining 9 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JJ-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0CE-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XF-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-PL-A8LX-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13J'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XV-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XR-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13I'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-OK-A5Q2-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A13G-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A140-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XS-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0DA-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XL-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JI-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A5ZX-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A6VV-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A13E-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A27V-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-2F-A9KT'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A13F-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7519-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XC-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13J'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-GU-A42R'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0CG-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-PL-A8LV-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A0C8'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A3Z6-01'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-Y6-A8TL-01'. Combining 5 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XY-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SI-01'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JC-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-XQ-A8TA-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1X5-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7521-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YC-A9TC'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13I'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EL'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A27W-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0CJ-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-MG-AAMC-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A13D-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SK-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-S3-AA15-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A27T-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A145-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1Y3-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1Y2-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EL'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-2F-A9KT'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-S3-AA12-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1X6-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1J8-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-PL-A8LZ-01'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A141-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-X4-A8KS-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0DB-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-3C-AALJ-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XZ-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0CH-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-GU-A42R'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1Y1-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-PL-A8LY-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-3C-AALI-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7525-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JD-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SJ-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A0C8'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1J9-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JE-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7523-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A27N-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A13Y-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A73X-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A27R-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A73U-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1X7-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YC-A9TC'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A9WI-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XB-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SL-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1XW-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-D8-A1JT-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SH-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-EW-A423-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-A7-A0D9-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-WW-A8ZI-01'. Combining 8 files.
# Epoch: 20, Loss: 0.0814, Train Error: 0.0277
# Start Testing
#
# True Bag Label: [0.]  Predicted Bag Label: [0.]
#
# True Bag Label: [0.]  Predicted Bag Label: [0.]
#
# True Bag Label: [0.]  Predicted Bag Label: [0.]
#
# True Bag Label: [0.]  Predicted Bag Label: [0.]
#
# True Bag Label: [0.]  Predicted Bag Label: [0.]
# Warning: Multiple matches found for slide id partial: 'TCGA-Y6-A9XI-01'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7522-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7510-01'. Combining 2 files.
#
# Test Set, Loss: 0.3489, Test Error: 0.1139

# %% [markdown]
# ## PROSTATE + BLADDER

# %%
# Jupyter Notebook version of main.py

import numpy as np
import torch
import torch.optim as optim
import torch.utils.data as data
from torch.autograd import Variable
from torch.utils.data import random_split, ConcatDataset, DataLoader

# Import your dataset and models
from dataloader import HistopathologyDataset
from model import Attention, GatedAttention

# ---------------------------
# Set parameters manually:
# ---------------------------
epochs = 20
lr = 0.0005
reg = 1e-4
# Use your actual paths to the folder (or file) containing your .pt embeddings 
# and the CSV file with labels.
# (Note: if your HistopathologyDataset expects a directory, make sure you supply that.)
# Paths for Cancer Prostate
embeddings_dir_prostate = "/data/temporary/amirhosein/model_script_prostate/pt_files/"
labels_csv_prostate = "/data/temporary/amirhosein/Prostate_Project/prostate_tp53_labels.csv"

# Paths for Cancer Bladder
embeddings_dir_bladder = "/data/temporary/amirhosein/model_script_bladder/pt_files/"
labels_csv_bladder = "/data/temporary/amirhosein/bladder_project/bladder_tp53_labels.csv"


input_dim = 1024
model_type = "attention"   # Choose either "attention" or "gated_attention"
no_cuda = False

cuda = (not no_cuda) and torch.cuda.is_available()

# ---------------------------
# Set seeds and print status:
# ---------------------------
torch.manual_seed(1)
if cuda:
    torch.cuda.manual_seed(1)
    print('\nGPU is ON!')

# ---------------------------
# Create dataset objects.
# ---------------------------
dataset_prostate = HistopathologyDataset(embeddings_dir_prostate, labels_csv_prostate)
dataset_bladder = HistopathologyDataset(embeddings_dir_bladder, labels_csv_bladder)


# Suppose you want 80% of Cancer C for training and 20% for testing.
total_prostate = len(dataset_prostate)
train_size_prostate = int(0.8 * total_prostate)
test_size_prostate  = total_prostate - train_size_prostate

dataset_prostate_train, dataset_prostate_test = random_split(dataset_prostate, [train_size_prostate, test_size_prostate])

train_dataset = ConcatDataset([dataset_bladder, dataset_prostate_train])
test_dataset  = dataset_prostate_test  # held-out portion from Cancer C

loader_kwargs = {'num_workers': 0, 'pin_memory': True} if cuda else {}
train_loader = data.DataLoader(train_dataset, batch_size=1, shuffle=True, **loader_kwargs)
test_loader  = data.DataLoader(test_dataset, batch_size=1, shuffle=False, **loader_kwargs)

# ---------------------------
# Initialize the Model:
# ---------------------------
print('Initializing Model')
if model_type == 'attention':
    model = Attention(input_dim=input_dim)
elif model_type == 'gated_attention':
    model = GatedAttention(input_dim=input_dim)
else:
    raise ValueError("Unknown model type. Choose 'attention' or 'gated_attention'.")

if cuda:
    model.cuda()

optimizer = optim.Adam(model.parameters(), lr=lr, betas=(0.9, 0.999), weight_decay=reg)

# ---------------------------
# Define training and testing functions:
# ---------------------------
def train(epoch):
    model.train()
    train_loss = 0.0
    train_error = 0.0
    for batch_idx, (data_batch, label) in enumerate(train_loader):
        if cuda:
            data_batch, label = data_batch.cuda(), label.cuda()
        data_batch, label = Variable(data_batch), Variable(label)
    
        optimizer.zero_grad()
        loss, _ = model.calculate_objective(data_batch, label)
        train_loss += loss.item()
        error, _ = model.calculate_classification_error(data_batch, label)
        train_error += error
    
        loss.backward()
        optimizer.step()
    
    train_loss /= len(train_loader)
    train_error /= len(train_loader)
    print('Epoch: {}, Loss: {:.4f}, Train Error: {:.4f}'.format(epoch, train_loss, train_error))
    
def test():
    model.eval()
    test_loss = 0.0
    test_error = 0.0
    with torch.no_grad():
        for batch_idx, (data_batch, label) in enumerate(test_loader):
            if cuda:
                data_batch, label = data_batch.cuda(), label.cuda()
            data_batch, label = Variable(data_batch), Variable(label)
            loss, attention_weights = model.calculate_objective(data_batch, label)
            test_loss += loss.item()
            error, predicted_label = model.calculate_classification_error(data_batch, label)
            test_error += error
    
            if batch_idx < 5:
                print('\nTrue Bag Label: {}  Predicted Bag Label: {}'
                      .format(label.cpu().numpy()[0], predicted_label.cpu().numpy()[0]))
    
    test_loss /= len(test_loader)
    test_error /= len(test_loader)
    print('\nTest Set, Loss: {:.4f}, Test Error: {:.4f}'.format(test_loss, test_error))
    
# ---------------------------
# Run training and testing:
# ---------------------------
print('Start Training')
for epoch in range(1, epochs + 1):
    train(epoch)
print('Start Testing')
test()
# Out:
# GPU is ON!
# Warning: No matching .pt file found for slide id partial: 'TCGA-DK-A6B6'. Skipping this entry.
# Warning: No matching .pt file found for slide id partial: 'TCGA-XF-AAN3'. Skipping this entry.
# Warning: No matching .pt file found for slide id partial: 'TCGA-FD-A3B5'. Skipping this entry.
# Warning: No matching .pt file found for slide id partial: 'TCGA-ZF-AA54'. Skipping this entry.
# Warning: No matching .pt file found for slide id partial: 'TCGA-ZF-AA4W'. Skipping this entry.
# Warning: No matching .pt file found for slide id partial: 'TCGA-FD-A3SP'. Skipping this entry.
# Initializing Model
# Start Training
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-WW-A8ZI-01'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13J'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-X4-A8KS-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SH-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-X4-A8KQ-01'. Combining 9 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7521-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A0C8'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13I'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-Y6-A8TL-01'. Combining 5 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SI-01'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-GU-A42R'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A9WI-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YC-A9TC'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-GU-A42R'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7519-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-2F-A9KT'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SL-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-XQ-A8TA-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7523-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13J'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SJ-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A0C8'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EL'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SK-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13I'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YC-A9TC'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-2F-A9KT'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7525-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EL'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-MG-AAMC-01'. Combining 2 files.
# Epoch: 1, Loss: 0.5515, Train Error: 0.2566
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EL'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SK-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13J'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-2F-A9KT'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7525-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7519-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SJ-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-2F-A9KT'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-XQ-A8TA-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7523-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-X4-A8KQ-01'. Combining 9 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SH-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-Y6-A8TL-01'. Combining 5 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SL-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A9WI-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-GU-A42R'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13I'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-MG-AAMC-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YC-A9TC'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EL'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7521-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A0C8'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SI-01'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-GU-A42R'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13I'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A0C8'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YC-A9TC'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13J'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-WW-A8ZI-01'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-X4-A8KS-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Epoch: 2, Loss: 0.4559, Train Error: 0.2087
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13J'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-GU-A42R'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A9WI-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-GU-A42R'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7519-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YC-A9TC'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-2F-A9KT'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7523-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A0C8'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-MG-AAMC-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-Y6-A8TL-01'. Combining 5 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7525-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-WW-A8ZI-01'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YC-A9TC'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SH-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-X4-A8KQ-01'. Combining 9 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SK-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-X4-A8KS-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SI-01'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-XQ-A8TA-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SJ-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EL'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7521-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13I'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-2F-A9KT'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SL-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EL'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A0C8'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13J'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13I'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Epoch: 3, Loss: 0.4071, Train Error: 0.1793
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SI-01'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7521-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-X4-A8KQ-01'. Combining 9 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-2F-A9KT'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SH-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13J'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SL-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7523-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A0C8'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-MG-AAMC-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YC-A9TC'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7519-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13I'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-GU-A42R'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13J'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-Y6-A8TL-01'. Combining 5 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YC-A9TC'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A0C8'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-XQ-A8TA-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EL'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-2F-A9KT'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SK-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-GU-A42R'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EJ'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EO'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EL'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-WW-A8ZI-01'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EC'. Combining 7 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-X4-A8KS-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A9WI-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3B'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-BL-A13I'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-YL-A8SJ-01'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2ES'. Combining 3 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A3Z7'. Combining 6 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7525-01'. Combining 2 files.
# Epoch: 4, Loss: 0.3423, Train Error: 0.1546
# Warning: Multiple matches found for slide id partial: 'TCGA-GU-A42R'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G9-7523-01'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A2EL'. Combining 2 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-AA3F'. Combining 8 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-FJ-A871'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.
# Warning: Multiple matches found for slide id partial: 'TCGA-G2-A3IB'. Combining 4 files.

# %% [markdown]
# ## Prostate + Breast

# %%
# Jupyter Notebook version of main.py

import numpy as np
import torch
import torch.optim as optim
import torch.utils.data as data
from torch.autograd import Variable
from torch.utils.data import random_split, ConcatDataset, DataLoader

# Import your dataset and models
from dataloader import HistopathologyDataset
from model import Attention, GatedAttention

# ---------------------------
# Set parameters manually:
# ---------------------------
epochs = 20
lr = 0.0005
reg = 1e-4
# Use your actual paths to the folder (or file) containing your .pt embeddings 
# and the CSV file with labels.
# (Note: if your HistopathologyDataset expects a directory, make sure you supply that.)
# Paths for Cancer Prostate
embeddings_dir_prostate = "/data/temporary/amirhosein/model_script_prostate/pt_files/"
labels_csv_prostate = "/data/temporary/amirhosein/Prostate_Project/prostate_tp53_labels.csv"

# Paths for Cancer Breast
embeddings_dir_breast = "/data/temporary/amirhosein/modelscript_breast/pt_files/"
labels_csv_breast = "/data/temporary/amirhosein/breast_Project(subdirectories)/breast_tp53_labels.csv"

input_dim = 1024
model_type = "attention"   # Choose either "attention" or "gated_attention"
no_cuda = False

cuda = (not no_cuda) and torch.cuda.is_available()

# ---------------------------
# Set seeds and print status:
# ---------------------------
torch.manual_seed(1)
if cuda:
    torch.cuda.manual_seed(1)
    print('\nGPU is ON!')

# ---------------------------
# Create dataset objects.
# ---------------------------
dataset_prostate = HistopathologyDataset(embeddings_dir_prostate, labels_csv_prostate)
dataset_breast = HistopathologyDataset(embeddings_dir_breast, labels_csv_breast)


# Suppose you want 80% of Cancer C for training and 20% for testing.
total_prostate = len(dataset_prostate)
train_size_prostate = int(0.8 * total_prostate)
test_size_prostate  = total_prostate - train_size_prostate

dataset_prostate_train, dataset_prostate_test = random_split(dataset_prostate, [train_size_prostate, test_size_prostate])

train_dataset = ConcatDataset([dataset_breast, dataset_prostate_train])
test_dataset  = dataset_prostate_test  # held-out portion from Cancer C

loader_kwargs = {'num_workers': 0, 'pin_memory': True} if cuda else {}
train_loader = data.DataLoader(train_dataset, batch_size=1, shuffle=True, **loader_kwargs)
test_loader  = data.DataLoader(test_dataset, batch_size=1, shuffle=False, **loader_kwargs)

# ---------------------------
# Initialize the Model:
# ---------------------------
print('Initializing Model')
if model_type == 'attention':
    model = Attention(input_dim=input_dim)
elif model_type == 'gated_attention':
    model = GatedAttention(input_dim=input_dim)
else:
    raise ValueError("Unknown model type. Choose 'attention' or 'gated_attention'.")

if cuda:
    model.cuda()

optimizer = optim.Adam(model.parameters(), lr=lr, betas=(0.9, 0.999), weight_decay=reg)

# ---------------------------
# Define training and testing functions:
# ---------------------------
def train(epoch):
    model.train()
    train_loss = 0.0
    train_error = 0.0
    for batch_idx, (data_batch, label) in enumerate(train_loader):
        if cuda:
            data_batch, label = data_batch.cuda(), label.cuda()
        data_batch, label = Variable(data_batch), Variable(label)
    
        optimizer.zero_grad()
        loss, _ = model.calculate_objective(data_batch, label)
        train_loss += loss.item()
        error, _ = model.calculate_classification_error(data_batch, label)
        train_error += error
    
        loss.backward()
        optimizer.step()
    
    train_loss /= len(train_loader)
    train_error /= len(train_loader)
    print('Epoch: {}, Loss: {:.4f}, Train Error: {:.4f}'.format(epoch, train_loss, train_error))
    
def test():
    model.eval()
    test_loss = 0.0
    test_error = 0.0
    with torch.no_grad():
        for batch_idx, (data_batch, label) in enumerate(test_loader):
            if cuda:
                data_batch, label = data_batch.cuda(), label.cuda()
            data_batch, label = Variable(data_batch), Variable(label)
            loss, attention_weights = model.calculate_objective(data_batch, label)
            test_loss += loss.item()
            error, predicted_label = model.calculate_classification_error(data_batch, label)
            test_error += error
    
            if batch_idx < 5:
                print('\nTrue Bag Label: {}  Predicted Bag Label: {}'
                      .format(label.cpu().numpy()[0], predicted_label.cpu().numpy()[0]))
    
    test_loss /= len(test_loader)
    test_error /= len(test_loader)
    print('\nTest Set, Loss: {:.4f}, Test Error: {:.4f}'.format(test_loss, test_error))
    
# ---------------------------
# Run training and testing:
# ---------------------------
print('Start Training')
for epoch in range(1, epochs + 1):
    train(epoch)
print('Start Testing')
test()

# %% [markdown]
# ## PROSTATE

# %%
# Jupyter Notebook version of main.py

import numpy as np
import torch
import torch.optim as optim
import torch.utils.data as data
from torch.autograd import Variable

# Import your dataset and models
from dataloader import HistopathologyDataset
from model import Attention, GatedAttention

# ---------------------------
# Set parameters manually:
# ---------------------------
epochs = 20
lr = 0.0005
reg = 1e-4
# Use your actual paths to the folder (or file) containing your .pt embeddings 
# and the CSV file with labels.
# (Note: if your HistopathologyDataset expects a directory, make sure you supply that.)
embeddings_dir = "/data/temporary/amirhosein/model_script_prostate/pt_files/"
labels_csv = "/data/temporary/amirhosein/Prostate_Project/prostate_tp53_labels.csv"
input_dim = 1024
model_type = "attention"   # Choose either "attention" or "gated_attention"
no_cuda = False

cuda = (not no_cuda) and torch.cuda.is_available()

# ---------------------------
# Set seeds and print status:
# ---------------------------
torch.manual_seed(1)
if cuda:
    torch.cuda.manual_seed(1)
    print('\nGPU is ON!')

# ---------------------------
# Create dataset objects.
# ---------------------------
train_dataset = HistopathologyDataset(embeddings_dir, labels_csv)
test_dataset  = HistopathologyDataset(embeddings_dir, labels_csv)

loader_kwargs = {'num_workers': 0, 'pin_memory': True} if cuda else {}
train_loader = data.DataLoader(train_dataset, batch_size=1, shuffle=True, **loader_kwargs)
test_loader  = data.DataLoader(test_dataset, batch_size=1, shuffle=False, **loader_kwargs)

# ---------------------------
# Initialize the Model:
# ---------------------------
print('Initializing Model')
if model_type == 'attention':
    model = Attention(input_dim=input_dim)
elif model_type == 'gated_attention':
    model = GatedAttention(input_dim=input_dim)
else:
    raise ValueError("Unknown model type. Choose 'attention' or 'gated_attention'.")

if cuda:
    model.cuda()

optimizer = optim.Adam(model.parameters(), lr=lr, betas=(0.9, 0.999), weight_decay=reg)

# ---------------------------
# Define training and testing functions:
# ---------------------------
def train(epoch):
    model.train()
    train_loss = 0.0
    train_error = 0.0
    for batch_idx, (data_batch, label) in enumerate(train_loader):
        if cuda:
            data_batch, label = data_batch.cuda(), label.cuda()
        data_batch, label = Variable(data_batch), Variable(label)
    
        optimizer.zero_grad()
        loss, _ = model.calculate_objective(data_batch, label)
        train_loss += loss.item()
        error, _ = model.calculate_classification_error(data_batch, label)
        train_error += error
    
        loss.backward()
        optimizer.step()
    
    train_loss /= len(train_loader)
    train_error /= len(train_loader)
    print('Epoch: {}, Loss: {:.4f}, Train Error: {:.4f}'.format(epoch, train_loss, train_error))
    
def test():
    model.eval()
    test_loss = 0.0
    test_error = 0.0
    with torch.no_grad():
        for batch_idx, (data_batch, label) in enumerate(test_loader):
            if cuda:
                data_batch, label = data_batch.cuda(), label.cuda()
            data_batch, label = Variable(data_batch), Variable(label)
            loss, attention_weights = model.calculate_objective(data_batch, label)
            test_loss += loss.item()
            error, predicted_label = model.calculate_classification_error(data_batch, label)
            test_error += error
    
            if batch_idx < 5:
                print('\nTrue Bag Label: {}  Predicted Bag Label: {}'
                      .format(label.cpu().numpy()[0], predicted_label.cpu().numpy()[0]))
    
    test_loss /= len(test_loader)
    test_error /= len(test_loader)
    print('\nTest Set, Loss: {:.4f}, Test Error: {:.4f}'.format(test_loss, test_error))
    
# ---------------------------
# Run training and testing:
# ---------------------------
print('Start Training')
for epoch in range(1, epochs + 1):
    train(epoch)
print('Start Testing')
test()

# %% [markdown]
# # original CNN

# %% [markdown]
# ## PROSTATE + BLADDER + BREAST

# %% [markdown]
# # Jupyter Notebook version of main.py
#
# import numpy as np
# import torch
# import torch.optim as optim
# import torch.utils.data as data
# from torch.autograd import Variable
# from torch.utils.data import random_split, ConcatDataset, DataLoader
#
# # Import your dataset and models
# from dataloader import HistopathologyDataset
# from model_2 import Attention, GatedAttention
#
# # ---------------------------
# # Set parameters manually:
# # ---------------------------
# epochs = 20
# lr = 0.0005
# reg = 1e-4
# # Use your actual paths to the folder (or file) containing your .pt embeddings
# # and the CSV file with labels.
# # (Note: if your HistopathologyDataset expects a directory, make sure you supply that.)
# # Paths for Cancer Prostate
# embeddings_dir_prostate = "/data/temporary/amirhosein/model_script_prostate/pt_files/"
# labels_csv_prostate = "/data/temporary/amirhosein/Prostate_Project/prostate_tp53_labels.csv"
#
# # Paths for Cancer Bladder
# embeddings_dir_bladder = "/data/temporary/amirhosein/model_script_bladder/pt_files/"
# labels_csv_bladder = "/data/temporary/amirhosein/bladder_project/bladder_tp53_labels.csv"
#
# # Paths for Cancer Breast
# embeddings_dir_breast = "/data/temporary/amirhosein/modelscript_breast/pt_files/"
# labels_csv_breast = "/data/temporary/amirhosein/breast_Project(subdirectories)/breast_tp53_labels.csv"
#
# input_dim = 1024
# model_type = "attention"   # Choose either "attention" or "gated_attention"
# no_cuda = False
#
# cuda = (not no_cuda) and torch.cuda.is_available()
#
# # ---------------------------
# # Set seeds and print status:
# # ---------------------------
# torch.manual_seed(1)
# if cuda:
#     torch.cuda.manual_seed(1)
#     print('\nGPU is ON!')
#
# # ---------------------------
# # Create dataset objects.
# # ---------------------------
# dataset_prostate = HistopathologyDataset(embeddings_dir_prostate, labels_csv_prostate)
# dataset_bladder = HistopathologyDataset(embeddings_dir_bladder, labels_csv_bladder)
# dataset_breast = HistopathologyDataset(embeddings_dir_breast, labels_csv_breast)
#
#
# # Suppose you want 80% of Cancer C for training and 20% for testing.
# total_prostate = len(dataset_prostate)
# train_size_prostate = int(0.8 * total_prostate)
# test_size_prostate  = total_prostate - train_size_prostate
#
# dataset_prostate_train, dataset_prostate_test = random_split(dataset_prostate, [train_size_prostate, test_size_prostate])
#
# train_dataset = ConcatDataset([dataset_breast, dataset_bladder, dataset_prostate_train])
# test_dataset  = dataset_prostate_test  # held-out portion from Cancer C
#
# loader_kwargs = {'num_workers': 0, 'pin_memory': True} if cuda else {}
# train_loader = data.DataLoader(train_dataset, batch_size=1, shuffle=True, **loader_kwargs)
# test_loader  = data.DataLoader(test_dataset, batch_size=1, shuffle=False, **loader_kwargs)
#
# # ---------------------------
# # Initialize the Model:
# # ---------------------------
# print('Initializing Model')
# if model_type == 'attention':
#     model = Attention()
# elif model_type == 'gated_attention':
#     model = GatedAttention()
# else:
#     raise ValueError("Unknown model type. Choose 'attention' or 'gated_attention'.")
#
# if cuda:
#     model.cuda()
#
# optimizer = optim.Adam(model.parameters(), lr=lr, betas=(0.9, 0.999), weight_decay=reg)
#
# # ---------------------------
# # Define training and testing functions:
# # ---------------------------
# def train(epoch):
#     model.train()
#     train_loss = 0.0
#     train_error = 0.0
#     for batch_idx, (data_batch, label) in enumerate(train_loader):
#         if cuda:
#             data_batch, label = data_batch.cuda(), label.cuda()
#         data_batch, label = Variable(data_batch), Variable(label)
#
#         optimizer.zero_grad()
#         loss, _ = model.calculate_objective(data_batch, label)
#         train_loss += loss.item()
#         error, _ = model.calculate_classification_error(data_batch, label)
#         train_error += error
#
#         loss.backward()
#         optimizer.step()
#
#     train_loss /= len(train_loader)
#     train_error /= len(train_loader)
#     print('Epoch: {}, Loss: {:.4f}, Train Error: {:.4f}'.format(epoch, train_loss, train_error))
#
# def test():
#     model.eval()
#     test_loss = 0.0
#     test_error = 0.0
#     with torch.no_grad():
#         for batch_idx, (data_batch, label) in enumerate(test_loader):
#             if cuda:
#                 data_batch, label = data_batch.cuda(), label.cuda()
#             data_batch, label = Variable(data_batch), Variable(label)
#             loss, attention_weights = model.calculate_objective(data_batch, label)
#             test_loss += loss.item()
#             error, predicted_label = model.calculate_classification_error(data_batch, label)
#             test_error += error
#
#             if batch_idx < 5:
#                 print('\nTrue Bag Label: {}  Predicted Bag Label: {}'
#                       .format(label.cpu().numpy()[0], predicted_label.cpu().numpy()[0]))
#
#     test_loss /= len(test_loader)
#     test_error /= len(test_loader)
#     print('\nTest Set, Loss: {:.4f}, Test Error: {:.4f}'.format(test_loss, test_error))
#
# # ---------------------------
# # Run training and testing:
# # ---------------------------
# print('Start Training')
# for epoch in range(1, epochs + 1):
#     train(epoch)
# print('Start Testing')
# test()
